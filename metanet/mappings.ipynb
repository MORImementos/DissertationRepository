# %%
import pandas as pd

df = pd.read_csv("data/raw/Mapping.csv")

df
# Out:
#             name                                      hasSourceRole  \
# 0    Mapping_193  ['Role_Frame_Destructive_natural_process_destr...
# 1    Mapping_322                ['Role_Frame_Shepherding_shepherd']
# 2    Mapping_431  ['Role_Frame_Destructive_force_destroyed_entity']
# 3    Mapping_507  ['Role_Frame_Physical_structure_structure_crea...
# 4     Mapping_77                  ['Role_Frame_Heat_heat_x_schema']
# ..           ...                                                ...
# 640   Mapping_96  ['Role_Frame_Object_collection_smallest_collec...
# 641  Mapping_192  ['Role_Frame_Destructive_natural_process_destr...
# 642   Mapping_94            ['Role_Frame_Object_collection_bigger']
# 643  Mapping_231                     ['Role_Frame_Game_game_event']
# 644  Mapping_354                         ['Role_Frame_Size_entity']
#
#                                                  label  \
# 0    ['Corruption.corruption_effect<=Destructive_na...
# ...

# %%
df = df[['name', 'hasSourceRole', 'hasTargetRole', 'label', 'comment']]

# %%
df.to_csv("data/trimmed/Mapping.csv", index=False)
