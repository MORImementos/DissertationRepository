# %%
import pandas as pd

df = pd.read_csv("data/raw/LexicalUnit.csv")

df
# Out:
#                   name                                               type  \
# 0     LexicalUnit_6193  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 1     LexicalUnit_6664  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 2     LexicalUnit_1273  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 3     LexicalUnit_3084  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 4      LexicalUnit_582  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# ...                ...                                                ...
# 9019   LexicalUnit_968  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 9020  LexicalUnit_2313  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 9021  LexicalUnit_5383  ['LexicalUnit', 'NamedIndividual', 'LexicalUnit']
# 9022  LexicalUnit_4220  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
# 9023  LexicalUnit_1418  ['NamedIndividual', 'LexicalUnit', 'LexicalUnit']
#
#      isFromLanguage                          label  \
# ...

# %%
df = df[['name', 'label', 'hasLemma']]

# %%
df.to_csv("data/trimmed/LexicalUnit.csv", index=False)
