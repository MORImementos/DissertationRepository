# %%
import pandas as pd

df = pd.read_csv("data/raw/Binding.csv")

df
# Out:
#              name                                 hasBoundRole2  \
# 0      Binding_98    ['Role_Frame_Harm_to_living_entity_agent']
# 1     Binding_137               ['Role_Frame_Causation_effect']
# 2      Binding_84  ['Role_Frame_Bounded_entity_bounded_entity']
# 3     Binding_592      ['Role_Frame_Governing_action_governed']
# 4     Binding_701    ['Role_Frame_Experience_pain_experiencer']
# ...           ...                                           ...
# 1013  Binding_817          ['Role_Frame_Emotion_emotion_level']
# 1014  Binding_814       ['Role_Frame_Emotion_cause_of_emotion']
# 1015  Binding_472          ['Role_Frame_Affected_motion_mover']
# 1016  Binding_314   ['Role_Frame_Erosion_cause_of_destruction']
# 1017  Binding_688              ['Role_Frame_Relation_entity_1']
#
#                                            type  \
# 0     ['Binding', 'NamedIndividual', 'Binding']
# 1     ['Binding', 'NamedIndividual', 'Binding']
# 2     ['NamedIndividual', 'Binding', 'Binding']
# ...

# %%
df = df[['name', 'hasBoundRole1', 'hasBoundRole2', 'label']]

# %%
df.to_csv("data/trimmed/Binding.csv", index=False)
