# %%
import pandas as pd

df = pd.read_csv("data/raw/Role.csv")

df
# Out:
#                                             name  \
# 0          Role_Frame_Infectious_disease_disease
# 1                Role_Frame_Affected_motion_path
# 2                Role_Frame_Possession_possessed
# 3               Role_Frame_Sound_sound_intensity
# 4     Role_Frame_Proximal_distal_proximal_region
# ...                                          ...
# 2263                 Role_Frame_Crafting_purpose
# 2264     Role_Frame_Economy_economy_participants
# 2265                Role_Frame_Using_used_entity
# 2266                       Role_Frame_Drugs_drug
# 2267       Role_Frame_Factory_manufacturing_line
#
#                                      type                   hasName  \
# 0     ['Role', 'NamedIndividual', 'Role']               ['disease']
# 1     ['NamedIndividual', 'Role', 'Role']                  ['path']
# 2     ['Role', 'NamedIndividual', 'Role']             ['possessed']
# 3     ['NamedIndividual', 'Role', 'Role']       ['sound_intensity']
# ...

# %%
df.columns
# Out:
# Index(['name', 'type', 'hasName', 'hasRoleType', 'label',
#        'correspondsToFrameElement', 'hasDefinition'],
#       dtype='object')

# %%
df = df[['name', 'hasName', 'hasRoleType', 'label',
       'correspondsToFrameElement', 'hasDefinition']]

# %%
df.to_csv("data/trimmed/Role.csv", index=False)
