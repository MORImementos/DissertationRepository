# %%
import pandas as pd

df = pd.read_csv("data/raw/Example.csv")

df
# Out:
#               name               hasAnnotation isFromLanguage  \
# 0     Example_3011         ['chained by debt']    ['English']
# 1     Example_2610  ['government has catered']    ['English']
# 2     Example_4732     ['handed an education']    ['English']
# 3     Example_4724             ['income fell']    ['English']
# 4     Example_2566     ['government can cure']    ['English']
# ...            ...                         ...            ...
# 5605  Example_4220                         NaN    ['English']
# 5606   Example_197           ['treat poverty']    ['English']
# 5607  Example_3052                         NaN    ['English']
# 5608  Example_5539       ['money handed over']            NaN
# 5609   Example_987                         NaN    ['English']
#
#                                            type  \
# 0     ['Example', 'NamedIndividual', 'Example']
# 1     ['Example', 'NamedIndividual', 'Example']
# 2     ['Example', 'NamedIndividual', 'Example']
# ...

# %%
df = df[['name', 'hasAnnotation', 'hasSentence', 'Example.Construction', 'label', 'comment']]

# %%
df
# Out:
#               name               hasAnnotation  \
# 0     Example_3011         ['chained by debt']
# 1     Example_2610  ['government has catered']
# 2     Example_4732     ['handed an education']
# 3     Example_4724             ['income fell']
# 4     Example_2566     ['government can cure']
# ...            ...                         ...
# 5605  Example_4220                         NaN
# 5606   Example_197           ['treat poverty']
# 5607  Example_3052                         NaN
# 5608  Example_5539       ['money handed over']
# 5609   Example_987                         NaN
#
#                                             hasSentence  \
# 0     ['a consumer chained by debt', 'If you', 'wher...
# 1     ['Alberta Premier Rachel Notley responds to cl...
# 2     ['I resented them a little', 'until I watched ...
# 3     ['892 in 2009.', 'Their average income fell to...
# 4     ['Nahendeh MLA Shane Thompson has a suggestion...
# ...
