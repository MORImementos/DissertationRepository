# %%
import pandas as pd

df = pd.read_csv("data/raw/Frame.csv")

df
# Out:
#                               name isApplicableToLanguage  \
# 0                      Frame_Death            ['English']
# 1                    Frame_Gun_use            ['English']
# 2                Frame_Corporation            ['English']
# 3                      Frame_Smell            ['English']
# 4    Frame_Constructed_confinement            ['English']
# ..                             ...                    ...
# 952              Frame_Boundedness            ['English']
# 953                   Frame_Status            ['English']
# 954                 Frame_Interior            ['English']
# 955                    Frame_Dream            ['English']
# 956          Frame_Climate_anxiety            ['English']
#
#                                               hasRoles  \
# 0    ['Role_Frame_Death_death_protagonist', 'Role_F...
# 1    ['Role_Frame_Gun_use_gun_user', 'Role_Frame_Gu...
# 2    ['Role_Frame_Corporation_corporation_mission',...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 952                                                NaN
# 953                                                NaN
# 954                                                NaN
# 955                                                NaN
# 956                                                NaN
#
#                          hasName                                   type  \
# 0                      ['Death']  ['Frame', 'NamedIndividual', 'Frame']
# 1                    ['Gun use']  ['NamedIndividual', 'Frame', 'Frame']
# 2                ['Corporation']  ['NamedIndividual', 'Frame', 'Frame']
# 3                      ['Smell']  ['Frame', 'NamedIndividual', 'Frame']
# 4    ['Constructed confinement']  ['NamedIndividual', 'Frame', 'Frame']
# ..                           ...                                    ...
# 952              ['Boundedness']  ['NamedIndividual', 'Frame', 'Frame']
# 953                   ['Status']  ['NamedIndividual', 'Frame', 'Frame']
# 954                 ['Interior']  ['NamedIndividual', 'Frame', 'Frame']
# 955                    ['Dream']  ['NamedIndividual', 'Frame', 'Frame']
# 956          ['Climate anxiety']  ['NamedIndividual', 'Frame', 'Frame']
#
#            wasEnteredBy correspondsToFrameNet                  hasFrameType  \
# 0              ['Oana']             ['Death']                     ['Frame']
# 1              ['Oana']                   NaN                     ['Frame']
# 2             ['Oana,']                   NaN                     ['Frame']
# 3      ['Ellen, Elise']         ['Sensation']              ['Image Schema']
# 4          ['Metabot,']                   NaN                     ['Frame']
# ..                  ...                   ...                           ...
# 952       ['Ellen MV,']                   NaN              ['Image Schema']
# 953           ['Oana,']                   NaN                     ['Frame']
# 954       ['Ellen MV,']                   NaN  ['Composed', 'Image Schema']
# 955       ['Ellen MV,']                   NaN                     ['Frame']
# 956  ['MetaNet group,']                   NaN                     ['Frame']
#
#                                         hasLexicalUnit  \
# 0    ['LexicalUnit_2240', 'LexicalUnit_2238', 'Lexi...
# 1                                                  NaN
# 2    ['LexicalUnit_1983', 'LexicalUnit_1985', 'Lexi...
# 3    ['LexicalUnit_7673', 'LexicalUnit_7651', 'Lexi...
# 4    ['LexicalUnit_1851', 'LexicalUnit_1857', 'Lexi...
# ..                                                 ...
# 952  ['LexicalUnit_801', 'LexicalUnit_799', 'Lexica...
# 953                                                NaN
# 954  ['LexicalUnit_4818', 'LexicalUnit_4820', 'Lexi...
# 955  ['LexicalUnit_2730', 'LexicalUnit_2727', 'Lexi...
# 956  ['LexicalUnit_1284', 'LexicalUnit_1286', 'Lexi...
#
#                                            hasBindings  ...  \
# 0    ['Binding_225', 'Binding_223', 'Binding_224', ...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 952                                                NaN  ...
# 953                                                NaN  ...
# 954                                                NaN  ...
# 955                                                NaN  ...
# 956                                                NaN  ...
#
#              isRelatedToFrame hasInference hasAlias hasPersianCorrespondent  \
# 0                         NaN          NaN      NaN                     NaN
# 1                         NaN          NaN      NaN                     NaN
# 2                         NaN          NaN      NaN                     NaN
# 3                         NaN          NaN      NaN                     NaN
# 4                         NaN          NaN      NaN                     NaN
# ..                        ...          ...      ...                     ...
# 952  ['Frame_Bounded_region']          NaN      NaN                     NaN
# 953                       NaN          NaN      NaN                     NaN
# 954                       NaN          NaN      NaN                     NaN
# 955        ['Frame_Sleeping']          NaN      NaN                     NaN
# 956                       NaN          NaN      NaN                     NaN
#
#     hasProgramAlias isInCausalRelationWithFrame LUs_Lemmas LUs_Language  \
# 0               NaN                         NaN        NaN          NaN
# 1               NaN                         NaN        NaN          NaN
# 2               NaN                         NaN        NaN          NaN
# 3               NaN                         NaN        NaN          NaN
# 4               NaN                         NaN        NaN          NaN
# ..              ...                         ...        ...          ...
# 952             NaN                         NaN        NaN          NaN
# 953             NaN                         NaN        NaN          NaN
# 954             NaN                         NaN        NaN          NaN
# 955             NaN                         NaN        NaN          NaN
# 956             NaN                         NaN        NaN          NaN
#
#     ClosestFrenchframe ClosestSpanishframe
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ..                 ...                 ...
# 952                NaN                 NaN
# 953                NaN                 NaN
# 954                NaN                 NaN
# 955                NaN                 NaN
# 956                NaN                 NaN
#
# [957 rows x 39 columns]

# %%
df = df[['name', 'hasRoles', 'hasName', 'correspondsToFrameNet', 'hasFrameType', 'hasLexicalUnit', 'hasBindings', 'isInAScalarOppositionToFrame', 'hasDescription', 'incorporatesFrameAsRole', 'isSubcaseOfFrame', 'label', 'isSubprocessOfFrame', 'comment', 'LexicalUnits', 'Families', 'Mappings', 'isInFrameFamily', 'hasCulturalContent', 'makesUseOfFrame', 'isAPerspectiveOnFrame', 'isRelatedToFrame', 'hasInference', 'hasAlias', 'hasProgramAlias', 'isInCausalRelationWithFrame']]

# %%
df
# Out:
#                               name  \
# 0                      Frame_Death
# 1                    Frame_Gun_use
# 2                Frame_Corporation
# 3                      Frame_Smell
# 4    Frame_Constructed_confinement
# ..                             ...
# 952              Frame_Boundedness
# 953                   Frame_Status
# 954                 Frame_Interior
# 955                    Frame_Dream
# 956          Frame_Climate_anxiety
#
#                                               hasRoles  \
# 0    ['Role_Frame_Death_death_protagonist', 'Role_F...
# 1    ['Role_Frame_Gun_use_gun_user', 'Role_Frame_Gu...
# 2    ['Role_Frame_Corporation_corporation_mission',...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 952                                                NaN
# 953                                                NaN
# 954                                                NaN
# 955                                                NaN
# 956                                                NaN
#
#                          hasName correspondsToFrameNet  \
# 0                      ['Death']             ['Death']
# 1                    ['Gun use']                   NaN
# 2                ['Corporation']                   NaN
# 3                      ['Smell']         ['Sensation']
# 4    ['Constructed confinement']                   NaN
# ..                           ...                   ...
# 952              ['Boundedness']                   NaN
# 953                   ['Status']                   NaN
# 954                 ['Interior']                   NaN
# 955                    ['Dream']                   NaN
# 956          ['Climate anxiety']                   NaN
#
#                      hasFrameType  \
# 0                       ['Frame']
# 1                       ['Frame']
# 2                       ['Frame']
# 3                ['Image Schema']
# 4                       ['Frame']
# ..                            ...
# 952              ['Image Schema']
# 953                     ['Frame']
# 954  ['Composed', 'Image Schema']
# 955                     ['Frame']
# 956                     ['Frame']
#
#                                         hasLexicalUnit  \
# 0    ['LexicalUnit_2240', 'LexicalUnit_2238', 'Lexi...
# 1                                                  NaN
# 2    ['LexicalUnit_1983', 'LexicalUnit_1985', 'Lexi...
# 3    ['LexicalUnit_7673', 'LexicalUnit_7651', 'Lexi...
# 4    ['LexicalUnit_1851', 'LexicalUnit_1857', 'Lexi...
# ..                                                 ...
# 952  ['LexicalUnit_801', 'LexicalUnit_799', 'Lexica...
# 953                                                NaN
# 954  ['LexicalUnit_4818', 'LexicalUnit_4820', 'Lexi...
# 955  ['LexicalUnit_2730', 'LexicalUnit_2727', 'Lexi...
# 956  ['LexicalUnit_1284', 'LexicalUnit_1286', 'Lexi...
#
#                                            hasBindings  \
# 0    ['Binding_225', 'Binding_223', 'Binding_224', ...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 952                                                NaN
# 953                                                NaN
# 954                                                NaN
# 955                                                NaN
# 956                                                NaN
#
#     isInAScalarOppositionToFrame  \
# 0                ['Frame_Birth']
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 952      ['Frame_Unboundedness']
# 953                          NaN
# 954                          NaN
# 955                          NaN
# 956                          NaN
#
#                                         hasDescription  \
# 0    ['to be further split into perspectives later....
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 952  ['or other thing is spatially and/or temporall...
# 953                                                NaN
# 954  ['Interiors are the inside of a container or o...
# 955  ['and visions that involuntarily come to us wh...
# 956                                                NaN
#
#          incorporatesFrameAsRole  ... Mappings  \
# 0    ['Frame_Biological_entity']  ...       []
# 1                            NaN  ...       []
# 2                            NaN  ...       []
# 3                            NaN  ...       []
# 4                            NaN  ...       []
# ..                           ...  ...      ...
# 952                          NaN  ...       []
# 953                          NaN  ...       []
# 954                          NaN  ...       []
# 955                          NaN  ...       []
# 956                          NaN  ...       []
#
#                                        isInFrameFamily  \
# 0                                                  NaN
# 1                          ['Frame_family_Gun_debate']
# 2                     ['Frame_family_Economic_Frames']
# 3                   ['Frame_family_Perception_frames']
# 4    ['Frame_family_Motion_affecting_frames', 'Fram...
# ..                                                 ...
# 952  ['Frame_family_Image_Schemas', 'Frame_family_B...
# 953                                                NaN
# 954                                                NaN
# 955                                                NaN
# 956                                                NaN
#
#                                     hasCulturalContent  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    ['checked cultural scope for English and Spani...
# ..                                                 ...
# 952                                                NaN
# 953                                                NaN
# 954                                                NaN
# 955                                                NaN
# 956                                                NaN
#
#               makesUseOfFrame isAPerspectiveOnFrame          isRelatedToFrame  \
# 0                         NaN                   NaN                       NaN
# 1                         NaN                   NaN                       NaN
# 2                         NaN                   NaN                       NaN
# 3                         NaN                   NaN                       NaN
# 4                         NaN                   NaN                       NaN
# ..                        ...                   ...                       ...
# 952                       NaN                   NaN  ['Frame_Bounded_region']
# 953                       NaN                   NaN                       NaN
# 954                       NaN                   NaN                       NaN
# 955                       NaN                   NaN        ['Frame_Sleeping']
# 956  ['Frame_Climate_change']                   NaN                       NaN
#
#     hasInference hasAlias hasProgramAlias isInCausalRelationWithFrame
# 0            NaN      NaN             NaN                         NaN
# 1            NaN      NaN             NaN                         NaN
# 2            NaN      NaN             NaN                         NaN
# 3            NaN      NaN             NaN                         NaN
# 4            NaN      NaN             NaN                         NaN
# ..           ...      ...             ...                         ...
# 952          NaN      NaN             NaN                         NaN
# 953          NaN      NaN             NaN                         NaN
# 954          NaN      NaN             NaN                         NaN
# 955          NaN      NaN             NaN                         NaN
# 956          NaN      NaN             NaN                         NaN
#
# [957 rows x 26 columns]
