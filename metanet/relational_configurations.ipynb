# %%
import pandas as pd

df = pd.read_csv("data/raw/RelationalConfiguration.csv")

df
# Out:
#                                 name hasMetaphoricityScore  \
# 0              FramesPerspectiveOnCM               ['0.6']
# 1         SubcaseOfFramesRelatedByCM               ['0.7']
# 2               TFrameIsRoleInSFrame              ['-0.5']
# 3          FramesDirectlyRelatedByCM               ['0.8']
# 4               TFrameUsesSFrame_1_2              ['-0.5']
# 5   FramesRelatedAtHigherLevelByCM_2               ['0.4']
# 6                FramesMakeUseOfCM_2               ['0.4']
# 7   FramesRelatedAtHigherLevelByCM_3               ['0.3']
# 8                   UsedByOtherFrame              ['-0.5']
# 9               TFrameUsesSFrame_3_4              ['-0.5']
# 10                SubcaseOfSameFrame              ['-0.5']
# 11    FramesRelatedAtHigherLevelByCM               ['0.5']
# 12                 FramesMakeUseOfCM               ['0.5']
#
#                       comment                               hasName  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'hasMetaphoricityScore', 'comment', 'hasName', 'hasDescription',
#        'type', 'label', 'hasQueryCode', 'isInRCGroup'],
#       dtype='object')

# %%
df = df[['name', 'hasMetaphoricityScore', 'comment', 'hasName', 'hasDescription',
       'label', 'isInRCGroup']]

# %%
df
# Out:
#                                 name hasMetaphoricityScore  \
# 0              FramesPerspectiveOnCM               ['0.6']
# 1         SubcaseOfFramesRelatedByCM               ['0.7']
# 2               TFrameIsRoleInSFrame              ['-0.5']
# 3          FramesDirectlyRelatedByCM               ['0.8']
# 4               TFrameUsesSFrame_1_2              ['-0.5']
# 5   FramesRelatedAtHigherLevelByCM_2               ['0.4']
# 6                FramesMakeUseOfCM_2               ['0.4']
# 7   FramesRelatedAtHigherLevelByCM_3               ['0.3']
# 8                   UsedByOtherFrame              ['-0.5']
# 9               TFrameUsesSFrame_3_4              ['-0.5']
# 10                SubcaseOfSameFrame              ['-0.5']
# 11    FramesRelatedAtHigherLevelByCM               ['0.5']
# 12                 FramesMakeUseOfCM               ['0.5']
#
#                       comment                               hasName  \
# ...
