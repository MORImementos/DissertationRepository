# %%
import pandas as pd
df = pd.read_csv("data/raw/Metaphor.csv")

df
# Out:
#                                                   name  \
# 0                 Metaphor_POWER_IS_A_POSSESSED_OBJECT
# 1                Metaphor_GOVERNMENT_IS_A_SLAVE_MASTER
# 2    Metaphor_ADDRESSING_POVERTY_IS_TREATING_AN_ILL...
# 3    Metaphor_BEING_IMPOVERISHED_IS_BEING_AT_A_LOW_...
# 4        Metaphor_TREATIES_ARE_INTERPERSONAL_CONTRACTS
# ..                                                 ...
# 869            Metaphor_WEALTH_IS_LINEAR_SPATIAL_SCALE
# 870                  Metaphor_FORMING_WORDS_IS_SHAPING
# 871                 Metaphor_COMMUNICATING_IS_POINTING
# 872  Metaphor_INCREASING_EVALUABILITY_OF_GOVERNMENT...
# 873          Metaphor_AID_TO_KNOWING_IS_A_LIGHT_SOURCE
#
#                                             type  \
# 0    ['Metaphor', 'NamedIndividual', 'Metaphor']
# 1    ['NamedIndividual', 'Metaphor', 'Metaphor']
# 2    ['Metaphor', 'NamedIndividual', 'Metaphor']
# 3    ['NamedIndividual', 'Metaphor', 'Metaphor']
# 4    ['NamedIndividual', 'Metaphor', 'Metaphor']
# ...

# %%
df = df[['name',  'hasSourceFrame', 'hasTargetFrame',
         'hasExample', 'comment',
       'hasMetaphorType', 'hasEntailment',
       'hasName',
       'isInMetaphorFamily', 'label', 'isSourceSubcaseOfMetaphor', 'hasMappings',
       'isEntailedByMetaphor', 'hasDescription', 'hasMetaphorLevel',
       'isTargetSubcaseOfMetaphor', 'hasAlias', 'makesUseOfMetaphor', 'isRelatedToMetaphor',
       'hasRelatedMetaphorDescription', 'isSourceAndTargetSubcaseOfMetaphor', 'hasExperientialBasis',
       'isRelatedToMetaphorBySource', 'isAMappingWithinMetaphor',
       'Metaphor_Comments', 'isADualOfMetaphor', 'isRelatedToMetaphorByTarget',
       'hasTransitiveSubpart2Metaphor', 'hasTransitiveSubpart1Metaphor',
       'Metaphor_Experientialbasis', 'Relatedmetaphor_Description']]

# %%
df
# Out:
#                                                   name  \
# 0                 Metaphor_POWER_IS_A_POSSESSED_OBJECT
# 1                Metaphor_GOVERNMENT_IS_A_SLAVE_MASTER
# 2    Metaphor_ADDRESSING_POVERTY_IS_TREATING_AN_ILL...
# 3    Metaphor_BEING_IMPOVERISHED_IS_BEING_AT_A_LOW_...
# 4        Metaphor_TREATIES_ARE_INTERPERSONAL_CONTRACTS
# ..                                                 ...
# 869            Metaphor_WEALTH_IS_LINEAR_SPATIAL_SCALE
# 870                  Metaphor_FORMING_WORDS_IS_SHAPING
# 871                 Metaphor_COMMUNICATING_IS_POINTING
# 872  Metaphor_INCREASING_EVALUABILITY_OF_GOVERNMENT...
# 873          Metaphor_AID_TO_KNOWING_IS_A_LIGHT_SOURCE
#
#                                hasSourceFrame                hasTargetFrame  \
# 0                        ['Frame_Possession']               ['Frame_Power']
# 1                     ['Frame_Work_scenario']          ['Frame_Government']
# ...

# %%
# def replace_str_list(val):
#     if pd.isna(val):
#         return ""
#     if isinstance(val, str) and val.strip().startswith("['") and val.strip().endswith("']"):
#         x = val.replace("['", "").replace("']", "")
#         return x
#     else:
#         return ""
#
# for col in df.columns:
#     df[col] = df[col].apply(replace_str_list)
# Out:
# C:\Users\micah\AppData\Local\Temp\ipykernel_3928\1012979411.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(replace_str_list)

# %%
df
# Out:
#     name                        hasSourceFrame            hasTargetFrame  \
# 0                             Frame_Possession               Frame_Power
# 1                          Frame_Work_scenario          Frame_Government
# 2         Frame_Treating_a_physical_affliction  Frame_Addressing_poverty
# 3                Frame_Being_at_a_Low_Location        Frame_Impoverished
# 4                              Frame_Contracts            Frame_Treaties
# ..   ...                                   ...                       ...
# 869                                Frame_Scale              Frame_Wealth
# 870                             Frame_Crafting       Frame_Forming_words
# 871                    Frame_Cause_to_perceive       Frame_Communication
# 872                                  Frame_TBD                 Frame_TBD
# 873                               Frame_Seeing             Frame_Knowing
#
#                                             hasExample  \
# ...
