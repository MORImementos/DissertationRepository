# %%
import pandas as pd

df = pd.read_csv("data/raw/Entailment.csv")

df
# Out:
#                name       hasEntailmentType hasTargetInference  \
# 0    Entailment_117  ['nullEntailmentType']  ['Inference_419']
# 1    Entailment_246  ['nullEntailmentType']  ['Inference_677']
# 2    Entailment_257              ['scalar']  ['Inference_699']
# 3    Entailment_111             ['control']  ['Inference_407']
# 4    Entailment_220  ['nullEntailmentType']  ['Inference_625']
# ..              ...                     ...                ...
# 256  Entailment_251       ['paired scales']  ['Inference_687']
# 257   Entailment_30  ['nullEntailmentType']  ['Inference_245']
# 258  Entailment_252       ['paired scales']  ['Inference_689']
# 259   Entailment_11  ['nullEntailmentType']  ['Inference_206']
# 260  Entailment_124  ['nullEntailmentType']  ['Inference_433']
#
#     hasSourceInference                                              label  \
# 0    ['Inference_418']  ['government has some degree...<=parents have ...
# ...

# %%
df = df[['name', 'hasEntailmentType', 'hasTargetInference', 'hasSourceInference', 'label', 'hasEntailedMetaphors']]

# %%
df.to_csv("data/trimmed/Entailment.csv", index=False)
