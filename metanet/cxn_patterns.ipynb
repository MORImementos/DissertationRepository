# %%
import pandas as pd
df = pd.read_csv("data/raw/CxnPattern.csv")

df
# Out:
#                          name  \
# 0          T_noun_poss_S_noun
# 1     T_noun_to_be_S_noun_adj
# 2            T_adj_mod_S_noun
# 3               S_verb_T_dobj
# 4     S_verb_Prep_T_noun_conj
# 5       T_noun_cop_S_noun_adj
# 6    T_noun_cop_S_noun_POSseq
# 7          S_noun_prep_T_noun
# 8          T_subj_S_verb_conj
# 9            S_adj_mod_T_noun
# 10         S_verb_T_dobj_conj
# 11  T_noun_poss_S_noun_POSseq
# 12           S_noun_of_T_noun
# 13         T_subj_conj_S_verb
# 14          T_noun_mod_S_noun
# 15              T_subj_S_verb
# 16         T_subj_aspV_S_verb
# 17         S_verb_Prep_T_noun
# 18     T_noun_cop_Prep_S_noun
#
#                                                type hasCxnPType  \
# 0   ['NamedIndividual', 'CxnPattern', 'CxnPattern']  ['sparql']
# 1   ['NamedIndividual', 'CxnPattern', 'CxnPattern']  ['sparql']
# 2   ['NamedIndividual', 'CxnPattern', 'CxnPattern']  ['sparql']
# 3   ['CxnPattern', 'NamedIndividual', 'CxnPattern']  ['sparql']
# ...

# %%
df = df[['name', 'label', 'comment', 'hasDescription', 'hasName', 'isInCxnPGroup']]
