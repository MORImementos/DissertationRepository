# %%
import pandas as pd

df = pd.read_csv("data/raw/FrameFamily.csv")

df
# Out:
#                                                   name           hasStatus  \
# 0                     Frame_family_Family_frame_family  ['in development']
# 1              Frame_family_Fluid_process_frame_family  ['in development']
# 2               Frame_family_Social_class_frame_family  ['in development']
# 3    Frame_family_Zealotry_Insanity_Worship_frame_f...                 NaN
# 4                       Frame_family_Spatial_relations                 NaN
# ..                                                 ...                 ...
# 232              Frame_family_Concealment_frame_family  ['in development']
# 233                        Frame_family_Benefit_frames                 NaN
# 234                 Frame_family_Morality_frame_family  ['in development']
# 235                      Frame_family_Democracy_frames                 NaN
# 236                 Frame_family_Politics_frame_family  ['in development']
#
#                                     isFrameSubfamilyOf  \
# ...

# %%
df = df[['name', 'isFrameSubfamilyOf', 'label', 'hasName', 'Frames']]

# %%
df.to_csv("data/trimmed/FrameFamily.csv", index=False)
