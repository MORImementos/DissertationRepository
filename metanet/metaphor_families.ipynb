# %%
import pandas as pd

df = pd.read_csv("data/raw/MetaphorFamily.csv")

df
# Out:
#                                                   name           hasStatus  \
# 0                     Metaphor_family_Cancer_Metaphors  ['in development']
# 1                     Metaphor_family_Nation_Metaphors  ['in development']
# 2    Metaphor_family_Change_of_State_Is_Change_of_L...  ['in development']
# 3                       Metaphor_family_Debt_Metaphors  ['in development']
# 4                 Metaphor_family_Possession_metaphors                 NaN
# ..                                                 ...                 ...
# 103  Metaphor_family_Disease_as_a_Source_Domain_Met...  ['in development']
# 104                  Metaphor_family_Disease_metaphors                 NaN
# 105               Metaphor_family_Governance_metaphors                 NaN
# 106  Metaphor_family_Economic_Status_as_a_Vertical_...  ['in development']
# 107                   Metaphor_family_Nature_metaphors                 NaN
#
#                                  isMetaphorSubfamilyOf  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'hasStatus', 'isMetaphorSubfamilyOf', 'type', 'label',
#        'hasName', 'hasDescription'],
#       dtype='object')

# %%
df = df[['name', 'isMetaphorSubfamilyOf', 'label',
       'hasName', 'hasDescription']]

# %%
df.to_csv("data/trimmed/MetaphorFamily.csv", index=False)
