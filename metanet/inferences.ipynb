# %%
import pandas as pd

df = pd.read_csv("data/raw/Inference.csv")

df
# Out:
#               name                                          label  \
# 0     Inference_56  ['The emotion or change in emotion_level...']
# 1    Inference_459                            ['Analyzing ideas']
# 2    Inference_182    ['The army engages in fighting against...']
# 3    Inference_579     ['Difficulties in progressing through...']
# 4    Inference_123       ['Being removed from the ground and...']
# ..             ...                                            ...
# 702  Inference_386       ['lack of containment enables mover...']
# 703  Inference_191          ['lighting conditions affect how...']
# 704  Inference_299                        ['change out of state']
# 705  Inference_446                           ['Appetizing foods']
# 706  Inference_303      ['a well-functioning/non-functioning...']
#
#                                  hasInferentialContent  \
# 0    ['The emotion or change in emotion_level occur...
# 1                                  ['Analyzing ideas']
# ...

# %%
df = df[['name', 'label', 'hasInferentialContent', 'isInferenceOfFrame', 'hasInferenceType']]

# %%
df
# Out:
#               name                                          label  \
# 0     Inference_56  ['The emotion or change in emotion_level...']
# 1    Inference_459                            ['Analyzing ideas']
# 2    Inference_182    ['The army engages in fighting against...']
# 3    Inference_579     ['Difficulties in progressing through...']
# 4    Inference_123       ['Being removed from the ground and...']
# ..             ...                                            ...
# 702  Inference_386       ['lack of containment enables mover...']
# 703  Inference_191          ['lighting conditions affect how...']
# 704  Inference_299                        ['change out of state']
# 705  Inference_446                           ['Appetizing foods']
# 706  Inference_303      ['a well-functioning/non-functioning...']
#
#                                  hasInferentialContent  \
# 0    ['The emotion or change in emotion_level occur...
# 1                                  ['Analyzing ideas']
# ...
